# %% [markdown]
# # 1. Importing libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Turning your project folder path into a string as prepared data.
path1 = r'/Users/elizabetenakamura/Documents/projects/python/data/prepared'

# %% [markdown]
# # Importing Data Frames

# %%
# Import and identify dataframes
ords_prods_merge = pd.read_pickle(os.path.join(path1,'ords_prods_merged_derived.pkl'))

# %%
# Create a subset of 1 million rows.
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 24)

# %%
df.head(10)
# Out:
#    Unnamed: 0.1_x  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0               0             0   2539329        1    prior             1
# 1               0             0   2539329        1    prior             1
# 2               0             0   2539329        1    prior             1
# 3               0             0   2539329        1    prior             1
# 4               0             0   2539329        1    prior             1
# 5               1             1   2398795        1    prior             2
# 6               1             1   2398795        1    prior             2
# 7               1             1   2398795        1    prior             2
# 8               1             1   2398795        1    prior             2
# 9               1             1   2398795        1    prior             2
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 0                   2                  8                     NaN
# ...

# %% [markdown]
# # 2. Grouping Data with Pandas

# %%
# Grouping data with pandas.
ords_prods_merge.groupby('product_name')

# %% [markdown]
# # 3. Aggregating Data

# %%
# Subset aggregation.
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
# Entire dataframe aggregation.
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# # 3. The overall trends in the mean, min, and max values might change when you analyze subsets.
# Overall Trends:
# The entire dataframe generally shows higher mean order numbers across departments, suggesting that it encompasses a broader spectrum of customer behaviors compared to the subset.
#
# Notable Differences:
# Department 21 exhibits the highest mean in both datasets, with a higher value in the subset (25.53) compared to the entire dataframe (22.90). Additionally, Department 10 shows a significant increase in the entire dataframe (20.19) compared to the subset (18.68).
#
# Consistent Departments:
# Some departments, such as 13 and 17, exhibit minimal differences between the two datasets. However, other departments, including 3, 9, and 12, display more pronounced variations.
#
# Conclusion:
# Overall, the entire dataframe reveals more frequent and diverse ordering patterns across departments when compared to the subset.

# %% [markdown]
# # 4. Aggregating Data with Transform

# %%
 # Create max_order column.
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/95/tcwc05191szglpgs3jtdf6tm0000gn/T/ipykernel_9521/2964966201.py:2: FutureWarning: The provided callable <function max at 0x106bbb560> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.drop(columns = ['eval_set'], inplace = True)

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1_x  Unnamed: 0_x  order_id  user_id  order_number  \
# 0                0             0   2539329        1             1
# 1                0             0   2539329        1             1
# 2                0             0   2539329        1             1
# 3                0             0   2539329        1             1
# 4                0             0   2539329        1             1
# 5                1             1   2398795        1             2
# 6                1             1   2398795        1             2
# 7                1             1   2398795        1             2
# 8                1             1   2398795        1             2
# 9                1             1   2398795        1             2
# 10               1             1   2398795        1             2
# 11               2             2    473747        1             3
# 12               2             2    473747        1             3
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0.1_x  Unnamed: 0_x  order_id  user_id  order_number  \
# 0                0             0   2539329        1             1
# 1                0             0   2539329        1             1
# 2                0             0   2539329        1             1
# 3                0             0   2539329        1             1
# 4                0             0   2539329        1             1
# 5                1             1   2398795        1             2
# 6                1             1   2398795        1             2
# 7                1             1   2398795        1             2
# 8                1             1   2398795        1             2
# 9                1             1   2398795        1             2
# 10               1             1   2398795        1             2
# 11               2             2    473747        1             3
# 12               2             2    473747        1             3
# ...

# %%
pd.options.display.max_rows = None

# %% [markdown]
# # 5. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# Create a loyalt_flay using loc function.
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Frequency of each distinct row in the Dataframe.
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
# Checking the Updated Output.
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1_x  Unnamed: 0_x  order_id  user_id  order_number  \
# 0                0             0   2539329        1             1
# 1                0             0   2539329        1             1
# 2                0             0   2539329        1             1
# 3                0             0   2539329        1             1
# 4                0             0   2539329        1             1
# 5                1             1   2398795        1             2
# 6                1             1   2398795        1             2
# 7                1             1   2398795        1             2
# 8                1             1   2398795        1             2
# 9                1             1   2398795        1             2
# 10               1             1   2398795        1             2
# 11               2             2    473747        1             3
# 12               2             2    473747        1             3
# ...

# %% [markdown]
# # Analysis of Spending Habits by Loyalty Category

# %%
# Basic Statistics of Spending Habits by Loyalty Category.
ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer     9.579346  1.0  14900.0
# New customer      10.059889  1.0  14900.0
# Regular customer   9.894698  1.0  14900.0

# %% [markdown]
# # 6. Create a spending flag for each user based on the average price across all their orders.

# %%
# Create a new column for the average spending of a customer
ords_prods_merge['average_spend'] = ords_prods_merge.groupby(['user_id'])['prices'].transform('mean')

# %%
# Check the new column
ords_prods_merge.head(20)
# Out:
#     Unnamed: 0.1_x  Unnamed: 0_x  order_id  user_id  order_number  \
# 0                0             0   2539329        1             1
# 1                0             0   2539329        1             1
# 2                0             0   2539329        1             1
# 3                0             0   2539329        1             1
# 4                0             0   2539329        1             1
# 5                1             1   2398795        1             2
# 6                1             1   2398795        1             2
# 7                1             1   2398795        1             2
# 8                1             1   2398795        1             2
# 9                1             1   2398795        1             2
# 10               1             1   2398795        1             2
# 11               2             2    473747        1             3
# 12               2             2    473747        1             3
# ...

# %%
# Assign spender tag to each customer
ords_prods_merge.loc[ords_prods_merge['average_spend']<10,'spender_flag']='low_spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_spend']>= 10, 'spender_flag'] = 'high_spender'

# %%
# Check spender flags
ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# spender_flag
# low_spender     31828060
# high_spender      576799
# Name: count, dtype: int64

# %% [markdown]
# # 7. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column.

# %%
# Create a new column for customer frequency flags based on the median values from 'days_since_prior_order' column
ords_prods_merge['customer_frequency'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform('median')

# %%
ords_prods_merge.head(20)
# Out:
#     Unnamed: 0.1_x  Unnamed: 0_x  order_id  user_id  order_number  \
# 0                0             0   2539329        1             1
# 1                0             0   2539329        1             1
# 2                0             0   2539329        1             1
# 3                0             0   2539329        1             1
# 4                0             0   2539329        1             1
# 5                1             1   2398795        1             2
# 6                1             1   2398795        1             2
# 7                1             1   2398795        1             2
# 8                1             1   2398795        1             2
# 9                1             1   2398795        1             2
# 10               1             1   2398795        1             2
# 11               2             2    473747        1             3
# 12               2             2    473747        1             3
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['customer_frequency'] > 20, 'frequency_flag'] = 'Non-frequent customer'
ords_prods_merge.loc[(ords_prods_merge['customer_frequency'] > 10) & (ords_prods_merge['customer_frequency'] <= 20), 'frequency_flag'] = 'Regular customer'
ords_prods_merge.loc[ords_prods_merge['customer_frequency'] <= 10, 'frequency_flag'] = 'Frequent customer'

# %%
# Check value counts for new column
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'customer_frequency', 'frequency_flag']].head(60)
# Out:
#     user_id  customer_frequency         frequency_flag
# 0         1                20.5  Non-frequent customer
# 1         1                20.5  Non-frequent customer
# 2         1                20.5  Non-frequent customer
# 3         1                20.5  Non-frequent customer
# 4         1                20.5  Non-frequent customer
# 5         1                20.5  Non-frequent customer
# 6         1                20.5  Non-frequent customer
# 7         1                20.5  Non-frequent customer
# 8         1                20.5  Non-frequent customer
# 9         1                20.5  Non-frequent customer
# 10        1                20.5  Non-frequent customer
# 11        1                20.5  Non-frequent customer
# 12        1                20.5  Non-frequent customer
# 13        1                20.5  Non-frequent customer
# 14        1                20.5  Non-frequent customer
# 15        1                20.5  Non-frequent customer
# ...

# %%
# Export dataframe with newly derived columns.
ords_prods_merge.to_pickle(os.path.join(path1, 'ords_prods_new_merged_derived.pkl'))
