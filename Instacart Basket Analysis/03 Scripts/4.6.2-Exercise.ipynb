# %% [markdown]
# # Importing libraries

# %%
# Importing libraries
import pandas as pd
import numpy as ny
import os

# %%
# Turning your project folder path into a string as prepared data.
path1 = r'/Users/elizabetenakamura/Documents/projects/python/data/prepared'

# %% [markdown]
# # Importing Data Frames

# %%
# Importing products_checked.csv
df_prods = pd.read_csv(os.path.join(path1, 'products_checked.csv'), index_col = False)

# %%
# Importing orders_products_combined.pkl.
orders_products_combined = pd.read_pickle(os.path.join(path1, 'orders_products_combined.pkl'))

# %% [markdown]
# # Information about Data Frames

# %%
orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           0   2539329        1    prior             1          2
# 2           0   2539329        1    prior             1          2
# 3           0   2539329        1    prior             1          2
# 4           0   2539329        1    prior             1          2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# # Merging products_checked with order_products_combined since they both have product_id.

# %%
# Inner merge data frame.
ords_prods_merge = orders_products_combined.merge(df_prods , on = ['product_id'] , indicator = 'match' )

# %%
ords_prods_merge.drop('_merge', axis = 1 )
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0                    0   2539329        1    prior             1          2
# 1                    0   2539329        1    prior             1          2
# 2                    0   2539329        1    prior             1          2
# 3                    0   2539329        1    prior             1          2
# 4                    0   2539329        1    prior             1          2
# ...                ...       ...      ...      ...           ...        ...
# 32404854       3421081   2977660   206209    prior            13          1
# 32404855       3421081   2977660   206209    prior            13          1
# 32404856       3421081   2977660   206209    prior            13          1
# 32404857       3421081   2977660   206209    prior            13          1
# 32404858       3421081   2977660   206209    prior            13          1
#
# ...

# %%
ords_prods_merge
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0                    0   2539329        1    prior             1          2
# 1                    0   2539329        1    prior             1          2
# 2                    0   2539329        1    prior             1          2
# 3                    0   2539329        1    prior             1          2
# 4                    0   2539329        1    prior             1          2
# ...                ...       ...      ...      ...           ...        ...
# 32404854       3421081   2977660   206209    prior            13          1
# 32404855       3421081   2977660   206209    prior            13          1
# 32404856       3421081   2977660   206209    prior            13          1
# 32404857       3421081   2977660   206209    prior            13          1
# 32404858       3421081   2977660   206209    prior            13          1
#
# ...
